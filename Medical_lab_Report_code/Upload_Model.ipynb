# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from huggingface_hub import login

login(token="hf_*************************************")  # حط هنا الـ token اللي نسخته

# %%
# ===========================================
# 1) تثبيت/تحديث huggingface_hub لو مش موجود
# ===========================================
# !pip install -q --upgrade huggingface_hub

# ===========================================
# 2) استيراد المكتبات
# ===========================================
from huggingface_hub import HfApi, login

# ===========================================
# 3) تسجيل الدخول بالتوكن
# ===========================================
token = "hf_*************************************"  # حط توكنك هنا
login(token=token)

# ===========================================
# 4) إعداد مسار الموديل والريبو
# ===========================================
merged_model_path = "/content/drive/MyDrive/fitrain/qwen-medical-merged"
repo_name = "qwen-medical-merged"
username = "omaraahmed"  # غيره لو اسم حسابك مختلف
full_repo_id = f"{username}/{repo_name}"

# ===========================================
# 5) إنشاء الريبو على Hugging Face (لو مش موجود)
# ===========================================
api = HfApi()
api.create_repo(
    repo_id=full_repo_id,
    token=token,
    exist_ok=True,  # لو الريبو موجود مسبقًا مش هيحصل error
    private=False    # لو عايز خاص خلي True
)

# ===========================================
# 6) رفع الموديل
# ===========================================
api.upload_folder(
    folder_path=merged_model_path,
    repo_id=full_repo_id,
    token=token
)

print(f"✅ Model uploaded successfully! Link: https://huggingface.co/{full_repo_id}")
# Out:
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#   ...cal-merged/tokenizer.json:  73%|#######2  | 8.30MB / 11.4MB
#   ...-merged/model.safetensors:   2%|2         | 42.0MB / 2.05GB
# ✅ Model uploaded successfully! Link: https://huggingface.co/omaraahmed/qwen-medical-merged
